# %%
#Cau 3 - VD1:
print("Hello World")
# Out:
# Hello World

# %%
#Cau 3 - VD2:
print("Albert Einstein đã từng nói: Một người không bao giờ mắc sai lầm không bao giờ thử bất kỳ điều gì mới.")
# Out:
# Albert Einstein đã từng nói: Một người không bao giờ mắc sai lầm không bao giờ thử bất kỳ điều gì mới.

# %%
#Cau 3 - VD3:
if 5 > 2:
     print("Five is greater than two!")
# Out:
# Five is greater than two!

# %%
#Cau 3 - VD4:
total = 1 + \
2 + \
3
print(total); print("Hello Python!")
# Out:
# 6
# Hello Python!

# %%
#Cau 3 - VD5:
if True:
   print("True")
else:
   print("False")
# Out:
# True

# %%
#Cau 3 - VD6:
#This is a comment
print("Hello, World")
# Out:
# Hello, World

# %%
#Cau 3 - VD7:
python3 test.py arg1 arg2 arg3.
# Out:
#   File "/tmp/ipython-input-656928829.py", line 2
#     python3 test.py arg1 arg2 arg3.
#             ^
# SyntaxError: invalid syntax

# %%
#Cau 3 - VD8:
import math
import os

# %%
#Cau 3 - VD9:
def add(a,b):
  result = a + b
  return result

# %%
#Cau 3 - VD10:
import math_libs
math_libs.add(4,5)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-2752454985.py in <cell line: 0>()
#       1 #Cau 3 - VD10:
# ----> 2 import math_libs
#       3 math_libs.add(4,5)
#
# ModuleNotFoundError: No module named 'math_libs'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#Cau 3 - VD11:
#module1.py
question = "What is the meaning of Life, the Universe, and Everything?"
answer = 42
#module2.py
question = "What is your quest?"
answer = "To seek the holy grail."
import module1
import module2
print(module1.question)
print(module2.question)
print(module1.answer)
print(module2.answer)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-777799285.py in <cell line: 0>()
#       5 question = "What is your quest?"
#       6 answer = "To seek the holy grail."
# ----> 7 import module1
#       8 import module2
#       9 print(module1.question)
#
# ModuleNotFoundError: No module named 'module1'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#Cau 4:
print("Chao cac ban!")
# Out:
# Chao cac ban!

# %%
#Cau 5:
ho = "Phạm Lê"
ten = "Gia Hân"
print("Họ và tên:",ho,ten)
# Out:
# Họ và tên: Phạm Lê Gia Hân

# %%
#Cau 6:
print("Minh về minh có nhớ ta?\nMười lăm năm ấy thiết tha mặn nồng.\nMình về mình có nhớ không?\nNhìn cây nhớ núi, nhìn sông nhớ nguồn.")
# Out:
# Minh về minh có nhớ ta?
# Mười lăm năm ấy thiết tha mặn nồng.
# Mình về mình có nhớ không?
# Nhìn cây nhớ núi, nhìn sông nhớ nguồn.

# %%
#Cau 7:
import sys
print("Số tham số:", len(sys.argv), "tham số.")
print("Danh sách tham số:", str(sys.argv))
# Out:
# Số tham số: 3 tham số.
# Danh sách tham số: ['/usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py', '-f', '/root/.local/share/jupyter/runtime/kernel-6eb8bc2b-8e6d-4474-8283-c8dee480e074.json']

# %%
#Cau 8:
print("* * * *\n")
print("*     *\n")
print("*     *\n")
print("* * * *")
# Out:
# * * * *
#
# *     *
#
# *     *
#
# * * * *

# %%
#Cau 9:
for i in range(4):
    print("*" * 9,"\n")
# Out:
# *********
#
# *********
#
# *********
#
# *********

# %%
#Cau 10:
print("    *")
print("   ***")
print("  *****")
print("   ***")
print("  *****")
print(" *******")
print("*********")
print("    *")
print("   ***")
# Out:
#     *
#    ***
#   *****
#    ***
#   *****
#  *******
# *********
#     *
#    ***

# %%
#Vidu Slide:
# Chương trình tính tổng hai số

# Nhập hai số từ bàn phím

so1 = int(input("Nhập số thứ nhất: "))

so2 = int(input("Nhập số thứ hai: "))

# Tính tổng tong so1 + so2
tong = so1 + so2
# Hiển thị kết quả

print("Tổng hai số là:", tong)
# Out:
# Nhập số thứ nhất: 2
# Nhập số thứ hai: 3
# Tổng hai số là: 5

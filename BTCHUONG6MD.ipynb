# %%
#cau 1:
from random import randrange

print("Chương trình xử lý List")
n = int(input("Nhập số phần tử: "))
lst = [0] * n

for i in range(n):
    lst[i] = randrange(-100, 100)

print("List ngẫu nhiên là:")
print(lst)

print("Mời bạn thêm số mới:")
value = int(input())
lst.append(value)
print(lst)

print("Bạn muốn đếm số nào:")
k = int(input())
dem = lst.count(k)
print(k, "xuất hiện", dem, "lần trong list")

def CheckPrime(n):
    if n < 2:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

demnt = 0
tongnt = 0
for x in lst:
    if CheckPrime(x):
        demnt += 1
        tongnt += x
print("Có", demnt, "số nguyên tố trong list")
print("Tổng =", tongnt)

lst.sort()
print("List sau khi sort:")
print(lst)

#Xóa list nhưng vẫn giữ biến
lst.clear()
print("List sau khi xóa:")
print(lst)
# Out:
# Chương trình xử lý List
# Nhập số phần tử: 5
# List ngẫu nhiên là:
# [-17, 44, -65, -9, -31]
# Mời bạn thêm số mới:
# 19
# [-17, 44, -65, -9, -31, 19]
# Bạn muốn đếm số nào:
# 19
# 19 xuất hiện 1 lần trong list
# Có 1 số nguyên tố trong list
# Tổng = 19
# List sau khi sort:
# [-65, -31, -17, -9, 19, 44]
# List sau khi xóa:
# []

# %%
#cau 2:
from random import randrange

lst = []

print("Nhập số phần tử:")
n = int(input())
for i in range(n):
    lst.append(randrange(0, 100))

print("List sau khi tạo ngẫu nhiên là:")
print(lst)

x = int(input("Mời bạn chèn thêm số mới: "))
lst.append(x)
print("List sau khi chèn:")
print(lst)

k = int(input("Mời nhập số để xóa: "))
while lst.count(k) > 0:
    lst.remove(k)
print("List sau khi xóa:")
print(lst)

def CheckDoiXung(lst):
    for i in range(len(lst)):
        if lst[i] != lst[len(lst) - i - 1]:
            return False
    return True

kt = CheckDoiXung(lst)
if kt == True:
    print("List đối xứng")
else:
    print("List không đối xứng")
# Out:
# Nhập số phần tử:
# 5
# List sau khi tạo ngẫu nhiên là:
# [46, 91, 85, 20, 20]
# Mời bạn chèn thêm số mới: 11
# List sau khi chèn:
# [46, 91, 85, 20, 20, 11]
# Mời nhập số để xóa: 20
# List sau khi xóa:
# [46, 91, 85, 11]
# List không đối xứng

# %%
#cau 3:
from random import randrange

def TaoMaTran(m, n):
    D = []
    for i in range(m):
        row = []
        for j in range(n):
            row.append(randrange(100))
        D.append(row)
    return D

def XuatMaTran(D):
    for row in D:
        for element in row:
            print(element, end='\t')
        print()

def LayDong(r):
    R = D[r]
    return R

def XuatList1Chieu(R):
    for element in R:
        print(element, end='\t')
    print()

def LayCot(c):
    C = []
    for i in range(len(D)):
        C.append(D[i][c])
    return C

def MAX(D):
    max = D[0][0]
    for i in range(len(D)):
        for j in range(len(D[i])):
            if max < D[i][j]:
                max = D[i][j]
    return max

print("Nhập số dòng:")
m = int(input())
print("Nhập số cột:")
n = int(input())
D = TaoMaTran(m, n)
XuatMaTran(D)

print("Mời bạn nhập dòng muốn xuất:")
r = int(input())
XuatList1Chieu(LayDong(r))

print("Mời bạn nhập cột muốn xuất:")
c = int(input())
XuatList1Chieu(LayCot(c))

max = MAX(D)
print("Số lớn nhất trong ma trận =", max)
# Out:
# Nhập số dòng:
# 3
# Nhập số cột:
# 3
# 49	23	82
# 70	51	89
# 98	44	80
# Mời bạn nhập dòng muốn xuất:
# 2
# 98	44	80
# Mời bạn nhập cột muốn xuất:
# 1
# 23	51	44
# Số lớn nhất trong ma trận = 98

# %%
#cau 4:
lst = [3, 0, 1, 5, 2]
x = 2

print("a)", lst[0])
print("b)", lst[3])
print("c)", lst[x])
print("d)", lst[-x])
print("e)", lst[x+1])
print("f)", lst[x] + 1)
print("g)", lst[lst[x]])
print("h)", lst[lst[lst[x]]])
# Out:
# a) 3
# b) 5
# c) 1
# d) 5
# e) 5
# f) 2
# g) 0
# h) 3

# %%
#cau 5:
lst = [20, 1, -34, 40, -8, 60, 1, 3]

print("a)", lst)
print("b)", lst[0:3])
print("c)", lst[4:8])
print("d)", lst[4:33])
print("e)", lst[-5:-3])
print("f)", lst[-22:3])
print("g)", lst[4:])
print("h)", lst[:])
print("i)", lst[:4])
print("j)", lst[1:5])
print("k)", -34 in lst)
print("l)", -34 not in lst)
print("m)", len(lst))
# Out:
# a) [20, 1, -34, 40, -8, 60, 1, 3]
# b) [20, 1, -34]
# c) [-8, 60, 1, 3]
# d) [-8, 60, 1, 3]
# e) [40, -8]
# f) [20, 1, -34]
# g) [-8, 60, 1, 3]
# h) [20, 1, -34, 40, -8, 60, 1, 3]
# i) [20, 1, -34, 40]
# j) [1, -34, 40, -8]
# k) True
# l) False
# m) 8

# %%
#cau 6:
import random

n = int(input("Nhập số phần tử: "))
lst = random.sample(range(0, 100), n)  #sample đảm bảo không trùng
print("List ngẫu nhiên không trùng:", lst)
# Out:
# Nhập số phần tử: 5
# List ngẫu nhiên không trùng: [65, 92, 36, 6, 58]

# %%
#cau 7:
n = int(input("Nhập số phần tử: "))
lst = []

for i in range(n):
    while True:
        x = int(input(f"Nhập phần tử thứ {i}: "))
        if i == 0 or x >= lst[-1]:
            lst.append(x)
            break
        else:
            print("Sai quy tắc, nhập lại (phải >= phần tử trước đó).")

print("Dãy số sau khi nhập:", lst)
# Out:
# Nhập số phần tử: 3
# Nhập phần tử thứ 0: 1
# Nhập phần tử thứ 1: 0
# Sai quy tắc, nhập lại (phải >= phần tử trước đó).
# Nhập phần tử thứ 1: 2
# Nhập phần tử thứ 2: 3
# Dãy số sau khi nhập: [1, 2, 3]

# %%
#cau 8:
n = int(input("Nhập số phần tử: "))
M = []

for i in range(n):
    M.append(float(input(f"Nhập M[{i}]: ")))

print("Dãy số ban đầu:", M)
M.sort(reverse=True)
print("Dãy số sau khi sắp xếp giảm dần:", M)
# Out:
# Nhập số phần tử: 4
# Nhập M[0]: 5
# Nhập M[1]: 7
# Nhập M[2]: 8
# Nhập M[3]: 1
# Dãy số ban đầu: [5.0, 7.0, 8.0, 1.0]
# Dãy số sau khi sắp xếp giảm dần: [8.0, 7.0, 5.0, 1.0]

# %%
#cau 9:
import math

def is_prime(n):
    if n < 2: return False
    for i in range(2, int(math.sqrt(n)) + 1):
        if n % i == 0: return False
    return True

M = list(map(int, input("Nhập mảng số tự nhiên (cách nhau bằng dấu cách): ").split()))

#dòng 1: số lẻ
odd = [x for x in M if x % 2 != 0]
print("Dòng 1:", odd, "-> có", len(odd), "số lẻ")

#dòng 2: số chẵn
even = [x for x in M if x % 2 == 0]
print("Dòng 2:", even, "-> có", len(even), "số chẵn")

#dòng 3: số nguyên tố
prime = [x for x in M if is_prime(x)]
print("Dòng 3:", prime, "-> có", len(prime), "số nguyên tố")

#dòng 4: không phải số nguyên tố
not_prime = [x for x in M if not is_prime(x)]
print("Dòng 4:", not_prime, "-> có", len(not_prime), "số không nguyên tố")
# Out:
# Nhập mảng số tự nhiên (cách nhau bằng dấu cách): 2 3 4 1 89 10 25
# Dòng 1: [3, 1, 89, 25] -> có 4 số lẻ
# Dòng 2: [2, 4, 10] -> có 3 số chẵn
# Dòng 3: [2, 3, 89] -> có 3 số nguyên tố
# Dòng 4: [4, 1, 10, 25] -> có 4 số không nguyên tố

# %%
#cau 10:
#Cộng 2 ma trận + Hoán vị (transpose)
def nhap_matrix(m, n, name):
    A = []
    print(f"Nhập ma trận {name}:")
    for i in range(m):
        row = list(map(int, input(f"Hàng {i+1}: ").split()))
        while len(row) != n:
            print("Sai số cột, nhập lại!")
            row = list(map(int, input(f"Hàng {i+1}: ").split()))
        A.append(row)
    return A

def in_matrix(A):
    for row in A:
        print(row)

def cong_matrix(A, B):
    return [[A[i][j] + B[i][j] for j in range(len(A[0]))] for i in range(len(A))]

def transpose(A):
    return [[A[j][i] for j in range(len(A))] for i in range(len(A[0]))]

m = int(input("Nhập số dòng: "))
n = int(input("Nhập số cột: "))

A = nhap_matrix(m, n, "A")
B = nhap_matrix(m, n, "B")

print("Ma trận A:")
in_matrix(A)
print("Ma trận B:")
in_matrix(B)

print("Tổng A + B:")
in_matrix(cong_matrix(A, B))

print("Hoán vị A:")
in_matrix(transpose(A))

print("Hoán vị B:")
in_matrix(transpose(B))
# Out:
# Nhập số dòng: 3
# Nhập số cột: 3
# Nhập ma trận A:
# Hàng 1: 24 67 10
# Hàng 2: 5 4 18
# Hàng 3: 9 3 51
# Nhập ma trận B:
# Hàng 1: 3 2 16
# Hàng 2: 82 77 56
# Hàng 3: 17 20 63
# Ma trận A:
# [24, 67, 10]
# [5, 4, 18]
# [9, 3, 51]
# Ma trận B:
# [3, 2, 16]
# [82, 77, 56]
# [17, 20, 63]
# Tổng A + B:
# [27, 69, 26]
# [87, 81, 74]
# [26, 23, 114]
# Hoán vị A:
# [24, 5, 9]
# [67, 4, 3]
# [10, 18, 51]
# Hoán vị B:
# [3, 82, 17]
# [2, 77, 20]
# [16, 56, 63]

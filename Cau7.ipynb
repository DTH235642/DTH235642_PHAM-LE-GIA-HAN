# %%
import sys
print("Số tham số:", len(sys.argv), "tham số.")
print("Danh sách tham số:", str(sys.argv))
# Out:
# Số tham số: 3 tham số.
# Danh sách tham số: ['/usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py', '-f', '/root/.local/share/jupyter/runtime/kernel-95022c25-7c70-4289-be81-1963cdd2c243.json']
